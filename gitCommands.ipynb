# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %cd /content/gdrive/My\ Drive/Programming/MLgenerator/
# Out:
# /content/gdrive/My Drive/Programming/MLgenerator

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Changes to be committed:
#   (use "git reset HEAD <file>..." to unstage)
#
# 	new file:   .gitignore
# 	modified:   data_prep.py
# 	new file:   main.ipynb

# %%
# !git add .

# %%
# !git reset __pycache__/data_prep.cpython-37.pyc

# %%
# !git config --global user.email "brahimfilali758@gmail.com"
# !git config --global user.name "ibrahim filali"

# %%
# !git commit -m "visualise a random pokemon"
# Out:
# [main b3f9650] visualise a random pokemon
#  3 files changed, 171 insertions(+), 1 deletion(-)
#  create mode 100644 .gitignore
#  create mode 100644 main.ipynb

# %%
# !git push origin main
# Out:
# Host key verification failed.
# fatal: Could not read from remote repository.
#
# Please make sure you have the correct access rights
# and the repository exists.
